# %%
import sys
import re

# %%
def extractSourceFileName(line):
    if re.findall('The full include-list for',line):
        flag = True
        index_right = line.rfind(':')
        index_left = line.rfind('/')+1
        return line[index_left:index_right]
    else:
        return None

# %%
def extractIncludeFileName(line):
    result = re.findall('".+"',line)
    if len(result) != 0:
        return result
    else:
        return re.findall('<.+>',line)

# %%
def addIncludeFileToList(index,log):
    includeList = []
    while index < len(log):
        line = log[index]
        print("line: ",line)
        res = extractIncludeFileName(line)
        print("res:",res)
        if len(res) != 0:
            includeList.append(res[0])
            index = index + 1
        else:
            break
    return includeList,index

# %%
def seveDict(fileDict):
    file = open('includefile.txt','w')
    for k,v in fileDict.items():
        file.write('The include-list for ' + k + ':' + '\n')
        for temp in v:
            file.write(temp+'\n')
        file.write('\n')
    file.close()

# %%
def saveDictAndSub(fileDict):
    file = open('includeSubFile.txt','w')
    flag = '        '
    for k,v in fileDict.items():
        file.write('The include-list for ' + k + ':' + '\n')
        for temp in v:
            searchIncludeRelation(temp,fileDict,file,flag)
            
    file.close()

# %%
def searchIncludeRelation(line,fileDict,file,flag):
    file.write(flag+line+'\n')
    fileName = re.findall('/*([A-Za-z0-9_]+\.*[pb]*\.h)',line)

    if(len(fileName) == 0):
        fileName = re.findall('<([A-Za-z0-9]+)>',line)
    print("fileName :")
    print(fileName[0])
    includeList = fileDict.get(fileName[0])
    if(includeList ==None):
        return
    for temp in includeList:
        searchIncludeRelation(temp,fileDict,file,flag+flag)

# %%
def main():
    log = []
    fileDict = {}
    for line in open("tmp.txt"):
        log.append(line[:-1]) #line[:-1]
    i=0
    while i < len(log):
        line = log[i]
        fileName = extractSourceFileName(line)
        if(fileName != None):
            print(fileName)
            includeList,i = addIncludeFileToList(i+1,log)
            fileDict[fileName] = includeList
        i = i+1
    saveDictAndSub(fileDict)

# %%
main()
# Out:
# private_data_proto.pb.h
# line:  #include <google/protobuf/arena.h>                           // for Arena
# res: ['<google/protobuf/arena.h>']
# line:  #include <google/protobuf/arenastring.h>                     // for ArenaStr...
# res: ['<google/protobuf/arenastring.h>']
# line:  #include <google/protobuf/extension_set.h>
# res: ['<google/protobuf/extension_set.h>']
# line:  #include <google/protobuf/generated_message_reflection.h>    // for AssignDe...
# res: ['<google/protobuf/generated_message_reflection.h>']
# line:  #include <google/protobuf/generated_message_table_driven.h>  // for Auxiliar...
# res: ['<google/protobuf/generated_message_table_driven.h>']
# line:  #include <google/protobuf/generated_message_util.h>          // for GenericSwap
# res: ['<google/protobuf/generated_message_util.h>']
# line:  #include <google/protobuf/message.h>                         // for Metadata
# res: ['<google/protobuf/message.h>']
# line:  #include <google/protobuf/repeated_field.h>
# res: ['<google/protobuf/repeated_field.h>']
# line:  #include <google/protobuf/stubs/logging.h>                   // for PROTOBUF...
# res: ['<google/protobuf/stubs/logging.h>']
# line:  #include <stddef.h>                                          // for size_t
# res: ['<stddef.h>']
# line:  #include <string>                                            // for string
# res: ['<string>']
# line:  #include <utility>                                           // for move
# res: ['<utility>']
# line:  #include "google/protobuf/extension_set.h"
# res: ['"google/protobuf/extension_set.h"']
# line:  #include "google/protobuf/message_lite.h"                    // for GetEmpty...
# res: ['"google/protobuf/message_lite.h"']
# line:  #include "google/protobuf/repeated_field.h"                  // for Repeated...
# res: ['"google/protobuf/repeated_field.h"']
# line:  #include "google/protobuf/stubs/logging.h"                   // for LogFinisher
# res: ['"google/protobuf/stubs/logging.h"']
# line:  #include "google/protobuf/stubs/port.h"                      // for int32
# res: ['"google/protobuf/stubs/port.h"']
# line:  #include "google/protobuf/stubs/stringpiece.h"               // for StringPiece
# res: ['"google/protobuf/stubs/stringpiece.h"']
# line:  namespace google { namespace protobuf { class Descriptor; } }
# res: []
# private_data_proto.pb.cc
# line:  #include "private_data_proto.pb.h"
# res: ['"private_data_proto.pb.h"']
# line:  #include <google/protobuf/generated_message_reflection.h>  // for AddDescrip...
# res: ['<google/protobuf/generated_message_reflection.h>']
# line:  #include <google/protobuf/io/coded_stream.h>               // for EpsCopyOut...
# res: ['<google/protobuf/io/coded_stream.h>']
# line:  #include <google/protobuf/reflection_ops.h>                // for ReflectionOps
# res: ['<google/protobuf/reflection_ops.h>']
# line:  #include <google/protobuf/wire_format.h>                   // for ComputeUnk...
# res: ['<google/protobuf/wire_format.h>']
# line:  #include <google/protobuf/wire_format_lite.h>              // for WireFormat...
# res: ['<google/protobuf/wire_format_lite.h>']
# line:  #include <atomic>                                          // for ATOMIC_VAR...
# res: ['<atomic>']
# line:  #include <new>                                             // for operator new
# res: ['<new>']
# line:  #include "google/protobuf/arena.h"                         // for Arena
# res: ['"google/protobuf/arena.h"']
# line:  #include "google/protobuf/arenastring.h"                   // for ArenaStrin...
# res: ['"google/protobuf/arenastring.h"']
# line:  #include "google/protobuf/generated_message_util.h"        // for SCCInfo
# res: ['"google/protobuf/generated_message_util.h"']
# line:  #include "google/protobuf/message.h"                       // for DynamicCas...
# res: ['"google/protobuf/message.h"']
# line:  #include "google/protobuf/metadata_lite.h"                 // for InternalMe...
# res: ['"google/protobuf/metadata_lite.h"']
# line:  #include "google/protobuf/parse_context.h"                 // for ParseContext
# res: ['"google/protobuf/parse_context.h"']
# line:  #include "google/protobuf/stubs/common.h"                  // for GOOGLE_PRO...
# res: ['"google/protobuf/stubs/common.h"']
# line:  #include "google/protobuf/stubs/once.h"                    // for once_flag
# res: ['"google/protobuf/stubs/once.h"']
# line:  #include "google/protobuf/unknown_field_set.h"             // for UnknownFie...
# res: ['"google/protobuf/unknown_field_set.h"']
# line:  namespace google { namespace protobuf { class EnumDescriptor; } }
# res: []
# data_service.h
# line:  #include <stdint.h>  // for uint8_t
# res: ['<stdint.h>']
# line:  #include <string>    // for string
# res: ['<string>']
# line:  #include <vector>    // for vector
# res: ['<vector>']
# line:  #include "test.h"    // for NUM_FIVE
# res: ['"test.h"']
# line:  namespace privateData { class Student; }
# res: []
# data_service.cpp
# line:  #include "data_service.h"
# res: ['"data_service.h"']
# line:  #include <algorithm>                // for copy, max
# res: ['<algorithm>']
# line:  #include <iostream>                 // for operator<<, endl, basic_ostream
# res: ['<iostream>']
# line:  #include <string>                   // for operator<<, string, char_traits
# res: ['<string>']
# line:  #include <vector>                   // for vector
# res: ['<vector>']
# line:  #include "private_data_proto.pb.h"  // for Student, Student_PhoneNumber
# res: ['"private_data_proto.pb.h"']
# line:  ---
# res: []
# main.cpp
# line:  #include "data_service.h"  // for printHolleWorld
# res: ['"data_service.h"']
# line:  ---
# res: []
# fileName :
# arena.h
# fileName :
# arenastring.h
# fileName :
# extension_set.h
# fileName :
# generated_message_reflection.h
# fileName :
# generated_message_table_driven.h
# fileName :
# generated_message_util.h
# fileName :
# message.h
# fileName :
# repeated_field.h
# fileName :
# logging.h
# fileName :
# stddef.h
# fileName :
# string
# fileName :
# utility
# fileName :
# extension_set.h
# fileName :
# message_lite.h
# fileName :
# repeated_field.h
# fileName :
# logging.h
# fileName :
# port.h
# fileName :
# stringpiece.h
# fileName :
# private_data_proto.pb.h
# fileName :
# arena.h
# fileName :
# arenastring.h
# fileName :
# extension_set.h
# fileName :
# generated_message_reflection.h
# fileName :
# generated_message_table_driven.h
# fileName :
# generated_message_util.h
# fileName :
# message.h
# fileName :
# repeated_field.h
# fileName :
# logging.h
# fileName :
# stddef.h
# fileName :
# string
# fileName :
# utility
# fileName :
# extension_set.h
# fileName :
# message_lite.h
# fileName :
# repeated_field.h
# fileName :
# logging.h
# fileName :
# port.h
# fileName :
# stringpiece.h
# fileName :
# generated_message_reflection.h
# fileName :
# coded_stream.h
# fileName :
# reflection_ops.h
# fileName :
# wire_format.h
# fileName :
# wire_format_lite.h
# fileName :
# atomic
# fileName :
# new
# fileName :
# arena.h
# fileName :
# arenastring.h
# fileName :
# generated_message_util.h
# fileName :
# message.h
# fileName :
# metadata_lite.h
# fileName :
# parse_context.h
# fileName :
# common.h
# fileName :
# once.h
# fileName :
# unknown_field_set.h
# fileName :
# stdint.h
# fileName :
# string
# fileName :
# vector
# fileName :
# test.h
# fileName :
# data_service.h
# fileName :
# stdint.h
# fileName :
# string
# fileName :
# vector
# fileName :
# test.h
# fileName :
# algorithm
# fileName :
# iostream
# fileName :
# string
# fileName :
# vector
# fileName :
# private_data_proto.pb.h
# fileName :
# arena.h
# fileName :
# arenastring.h
# fileName :
# extension_set.h
# fileName :
# generated_message_reflection.h
# fileName :
# generated_message_table_driven.h
# fileName :
# generated_message_util.h
# fileName :
# message.h
# fileName :
# repeated_field.h
# fileName :
# logging.h
# fileName :
# stddef.h
# fileName :
# string
# fileName :
# utility
# fileName :
# extension_set.h
# fileName :
# message_lite.h
# fileName :
# repeated_field.h
# fileName :
# logging.h
# fileName :
# port.h
# fileName :
# stringpiece.h
# fileName :
# data_service.h
# fileName :
# stdint.h
# fileName :
# string
# fileName :
# vector
# fileName :
# test.h

# %%
filedict
# Out:
# {'private_data_proto.pb.h': ['<google/protobuf/arena.h>',
#   '<google/protobuf/arenastring.h>',
#   '<google/protobuf/extension_set.h>',
#   '<google/protobuf/generated_message_reflection.h>',
#   '<google/protobuf/generated_message_table_driven.h>',
#   '<google/protobuf/generated_message_util.h>',
#   '<google/protobuf/message.h>',
#   '<google/protobuf/repeated_field.h>',
#   '<google/protobuf/stubs/logging.h>',
#   '<stddef.h>',
#   '<string>',
#   '<utility>',
#   '"google/protobuf/extension_set.h"',
#   '"google/protobuf/message_lite.h"',
#   '"google/protobuf/repeated_field.h"',
#   '"google/protobuf/stubs/logging.h"',
#   '"google/protobuf/stubs/port.h"',
#   '"google/protobuf/stubs/stringpiece.h"'],
#  'private_data_proto.pb.cc': ['"private_data_proto.pb.h"',
#   '<google/protobuf/generated_message_reflection.h>',
#   '<google/protobuf/io/coded_stream.h>',
#   '<google/protobuf/reflection_ops.h>',
#   '<google/protobuf/wire_format.h>',
#   '<google/protobuf/wire_format_lite.h>',
#   '<atomic>',
#   '<new>',
#   '"google/protobuf/arena.h"',
#   '"google/protobuf/arenastring.h"',
#   '"google/protobuf/generated_message_util.h"',
#   '"google/protobuf/message.h"',
#   '"google/protobuf/metadata_lite.h"',
#   '"google/protobuf/parse_context.h"',
#   '"google/protobuf/stubs/common.h"',
#   '"google/protobuf/stubs/once.h"',
#   '"google/protobuf/unknown_field_set.h"'],
#  'data_service.h': ['<stdint.h>', '<string>', '<vector>', '"test.h"'],
#  'data_service.cpp': ['"data_service.h"',
#   '<algorithm>',
#   '<iostream>',
#   '<string>',
#   '<vector>',
#   '"private_data_proto.pb.h"'],
#  'main.cpp': ['"data_service.h"']}

# %%
 filedict.get('private_data_proto.pb.h')
# Out:
# ['<google/protobuf/arena.h>',
#  '<google/protobuf/arenastring.h>',
#  '<google/protobuf/extension_set.h>',
#  '<google/protobuf/generated_message_reflection.h>',
#  '<google/protobuf/generated_message_table_driven.h>',
#  '<google/protobuf/generated_message_util.h>',
#  '<google/protobuf/message.h>',
#  '<google/protobuf/repeated_field.h>',
#  '<google/protobuf/stubs/logging.h>',
#  '<stddef.h>',
#  '<string>',
#  '<utility>',
#  '"google/protobuf/extension_set.h"',
#  '"google/protobuf/message_lite.h"',
#  '"google/protobuf/repeated_field.h"',
#  '"google/protobuf/stubs/logging.h"',
#  '"google/protobuf/stubs/port.h"',
#  '"google/protobuf/stubs/stringpiece.h"']

# %%
re.findall('/([A-Za-z0-9_]+\.h)','<google/protobuf/generated_message_util.h>')
# Out:
# ['generated_message_util.h']

# %%
key = re.findall('<([A-Za-z0-9]+)>','<str_ing>')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-63-555f0d0aabea> in <module>
#       1 key = re.findall('<([A-Za-z0-9]+)>','<str_ing>')
# ----> 2 key[0]
#
# IndexError: list index out of range

# %%
re.findall('/*([A-Za-z0-9_]+\.*[pb]*\.h)', '"google/protobuf/repeated_field.h"')
# Out:
# ['repeated_field.h']
